# %%
import csv
import numpy as np
from transformers import pipeline
from datasets import load_dataset
import pandas as pd
from jiwer import wer
from jarowinkler import *
import string

# %%
def add_text_to_csv(text, csv_file_path):
    # Open the CSV file for appending
    with open(csv_file_path, mode='a', newline='', encoding='utf-8') as csv_file:
        writer = csv.writer(csv_file)
        # Write the text to the CSV
        writer.writerow([text])

# %%
whisper = pipeline(
    "automatic-speech-recognition",
    model="openai/whisper-tiny.en",
    chunk_length_s=30,
)

# %%
wav2vec = pipeline(
    "automatic-speech-recognition",
    model="jonatasgrosman/wav2vec2-large-xlsr-53-english",
    chunk_length_s=30,
)
# Out:
# Some weights of the model checkpoint at jonatasgrosman/wav2vec2-large-xlsr-53-english were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at jonatasgrosman/wav2vec2-large-xlsr-53-english and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Could not load the `decoder` for jonatasgrosman/wav2vec2-large-xlsr-53-english. Defaulting to raw CTC. Error: No module named 'kenlm'
# Try to install `kenlm`: `pip install kenlm
# Try to install `pyctcdecode`: `pip install pyctcdecode

# %%
# Load the FLEURS dataset
fleurs_asr = load_dataset("google/fleurs", "en_us")
# Out:
# /Users/averyfield/Desktop/Bootcamp/flytechllm/.venv/lib/python3.11/site-packages/datasets/load.py:1454: FutureWarning: The repository for google/fleurs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/google/fleurs
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
# Function to transcribe audio
def transcribe(audio, model, output_csv_file):
    audio_data = {
        "raw": np.array(audio["array"]),  # The audio waveform
        "sampling_rate": audio["sampling_rate"]  # The sampling rate of the audio
    }
    english_text = model(audio_data)  # Perform ASR
    add_text_to_csv(english_text["text"], output_csv_file)  # Add the transcription to the CSV

# %%
# Directory and output file paths
whisper_output_csv_file = 'asr_outputs/whisper_output.csv'
audio_inputs = fleurs_asr["train"][:50]["audio"]

print('Whisper...')
for audio in audio_inputs:
    transcribe(audio, whisper, whisper_output_csv_file)
# Out:
# Whisper...

# %%
wave2vec_output_csv_file = 'asr_outputs/wave2vec_output.csv'
audio_inputs = fleurs_asr["train"][:50]["audio"]

print('Wave2vec..')
for audio in audio_inputs:
    transcribe(audio, wav2vec, wave2vec_output_csv_file)
# Out:
# Wave2vec..

# %%
original_text = fleurs_asr["train"][:50]["transcription"]
original_df = pd.DataFrame(original_text, columns=['Original_Transcription'])
original_df
# Out:
#                                Original_Transcription
# 0   a tornado is a spinning column of very low-pre...
# 1   former u.s. speaker of the house newt gingrich...
# 2   the island was first inhabited by the taínos a...
# 3   these nerve impulses can be sent so quickly th...
# 4   on september 24 1759 arthur guinness signed a ...
# 5   today timbuktu is an impoverished town althoug...
# 6   with the same time zone as hawaii the islands ...
# 7   hokuriku electric power co reported no effects...
# 8   massa is due to be out for at least the rest o...
# 9   pittman suggested that conditions wouldn't imp...
# 10  followers pursue certain ways of living or pra...
# 11  the protest started around 11:00 local time ut...
# 12  the amazon river is the second longest and the...
# 13  virgin have only purchased the good bank' of n...
# 14  with this arrangement in place this freedom mi...
# 15  its status declined during the twelfth century...
# 16  the civilisation flourished in the basins of t...
# 17  it was developed by john smith in the 1970s to...
# 18  for some understanding something about how air...
# 19  the original bill was drafted by former mayor ...
# 20  massa is due to be out for at least the rest o...
# 21  there were protests worldwide several criminal...
# 22  despite his comments he said he will be suppor...
# 23  un peacekeepers whom arrived in haiti after th...
# 24  the unmanned lunar orbiter chandrayaan-1 eject...
# 25  they normally offer higher bandwidth and bette...
# 26  unattended bags are a target for theft and can...
# 27  examples include control planning and scheduli...
# 28  other scientists argue that these plants are v...
# 29  in fact there is not one good thing to learn.l...
# 30  permits must be reserved in advance you must h...
# 31  the blade on a modern ice skate has a double e...
# 32  the outer-part we see when we look at the sun ...
# 33  this theory contradicts the claim that the moo...
# 34  another disadvantage of zoom lenses is that th...
# 35  a couple of thousand staff live here in summer...
# 36  unfortunately when you make a dvd it's borders...
# 37  visibility may also be restricted by falling o...
# 38  in essence the renaissance made a significant ...
# 39  historically most farmers were engaged in subs...
# 40  21-year-old jesus joined manchester city last ...
# 41  some people believe that experiencing many art...
# 42  northern rock had required support due to its ...
# 43  in the context of romanticism the geography mo...
# 44  officials for the city of amsterdam and the an...
# 45  we will endeavour to cut carbon dioxide emissi...
# 46  beijing will host the opening and closing cere...
# 47  after the fire the fortress was preserved and ...
# 48  within a few short years following the arrival...
# 49  shortly after the atlanta journal-constitution...

# %%
whisper_text = pd.read_csv('asr_outputs/whisper_output.csv', header=None, names=['Whisper_Transcription'])
whisper_text
# Out:
#                                 Whisper_Transcription
# 0    A tornado is a spinning column of very low pr...
# 1    Former US speaker of the house, Newt Gingrich...
# 2    The island was first inhabited by the Tianos ...
# 3    This nerve empulses can be sent so quickly th...
# 4    On September 24th 1759 Arthur Guinness signed...
# 5    Today, Timbuktu is an impoverished town, alth...
# 6    with the same time zone as Hawaii, the island...
# 7    Her crookie electric parkour reported no effe...
# 8    Masa is due to be out of for at least the res...
# 9    Pittman suggested that conditions wouldn't im...
# 10   Followers pursue certain ways of living or pr...
# 11   The protest started around 11-0-0 local time ...
# 12   The Amazon River is the second longest and th...
# 13   Version have only purchased the good bank of ...
# 14   With this arrangement in place, this freedom ...
# 15   Is status declined during the 12th century, m...
# 16   The civilization flourished in the basins of ...
# 17   It was developed by John Smith in the 1970s t...
# 18   For some, understanding something about how a...
# 19   The original bill was drafted by former mayor...
# 20   Masa is due to be out for at least the rest o...
# 21   There were protests worldwide, several crimin...
# 22   Despite his comments, he said he will be supp...
# 23   You and peacekeepers who arrived in Haiti aft...
# 24   The unmanned lunar orbiter, Chandrayan 1, inj...
# 25   They normally offer higher bandwidth and bett...
# 26   Unattended bags are a target for theft and ca...
# 27   Examples include control, planning and schedu...
# 28   Other scientists argue that these plants are ...
# 29   In fact, there's not one good thing to learn....
# 30   Permence must be reserved in advance. You mus...
# 31   The blade on a modern ice cape has a double e...
# 32   The outer part we see when we look at the sun...
# 33   This theory contradicts the claim that the Mo...
# 34   Another disadvantage of zoom lenses is that t...
# 35   A couple of thousand staff live here in summe...
# 36   Unfortunately, when you make a DVD, its borde...
# 37   Visibility may also be restricted by followin...
# 38   In essence, the Renaissance made a significan...
# 39   Historically, most farmers were engaged in su...
# 40   21-year-old Jesus joined Manchester City last...
# 41   Some people believe that experiencing many ar...
# 42   Northern Rock had required support due to its...
# 43   In the context of romanticism, the geography ...
# 44   Officials for the city of Amsterdam and the A...
# 45   We will endeavor to cut carbon dioxide emissi...
# 46   Beijing will host the opening at closed cerem...
# 47   After the fire, the fortress was preserved an...
# 48   Within a few short years following the arriva...
# 49   Shortly after, the Atlanta Journal Constituti...

# %%
wave2vec_text = pd.read_csv('asr_outputs/wave2vec_output.csv', header=None, names=['Wave2Vec_Transcription'])
wave2vec_text
# Out:
#                                Wave2Vec_Transcription
# 0   a tornado is a spinning column of very low-pre...
# 1   former ewsh speaker of the house neut gingrich...
# 2   the island was first inhabited by tetianos and...
# 3   these nerve impulses can be sent so quickly th...
# 4   on september twenty-fourth seventeen fifty nin...
# 5   today timbactu is an impoverished town althoug...
# 6   with the same time zown as hawai the islands a...
# 7   hokroky electric parko reported no effect from...
# 8   massa is due to be out for at least the rest o...
# 9   pitman suggested that conditions wuldn't impro...
# 10  followers pursue certain ways of living or pra...
# 11  the protest started around eleven the rozero l...
# 12  the amazon river is the second-longest and the...
# 13  version have only purchased the good bank of n...
# 14  with this arrangement in place this freedom mi...
# 15  a status declined during the twelfth century m...
# 16  the civilization flourished in the basins of t...
# 17  it was developed by john smith in the nineteen...
# 18  for some understanding something about how air...
# 19  the original bill was drafted by former mayor ...
# 20  massa is due to be out for at least the rest o...
# 21  there were protests worldwide several criminal...
# 22  despite his commets he said he wild be support...
# 23  uvan peacekeepers who arrived in haide after t...
# 24  the unmanned lunar orbiter chandryan wan eject...
# 25  they normally offer higher bandwithan better q...
# 26  unattended bags are a target for theft and can...
# 27  examples include control planning and scheduli...
# 28  other scientists argue that these plants are v...
# 29  in fact there is not one good thing to learn l...
# 30  permits must be reserved in advance you must h...
# 31  the blade on a modern ice cate has a double ed...
# 32  the outer part we see when we look at the sun ...
# 33  this theory contradicts the claim that the moo...
# 34  another disadvantage of zoomlenses is that the...
# 35  a couple of thousand staff live here in summer...
# 36  unfortunately when you make a debd its borders...
# 37  visibility may also be restricted by falling o...
# 38  in essence the renaissance made a significant ...
# 39  historically most pharmers were engaged in sub...
# 40  twenty-one year-old jesus joined manchester ci...
# 41  some people believe that experiencing many art...
# 42  northern rock had required support due to its ...
# 43  in the context of romanticism the geography-mo...
# 44  officials for the city of amsterdam and the an...
# 45  we will endeavor to cut carbon dioxide emissio...
# 46  beijin will host the opening antd closes cerem...
# 47  after the fire the fortress was preserved and ...
# 48  within a few short years following the arrival...
# 49  shortly after the atlanta journal constitution...

# %%
asr_analysis_df = pd.concat([original_df, whisper_text, wave2vec_text], axis=1)
# Remove punctuation and apply lower() to all text columns
asr_analysis_df = asr_analysis_df.applymap(lambda x: x.lower().translate(str.maketrans('', '', string.punctuation)) if isinstance(x, str) else x)
asr_analysis_df
# Out:
# /var/folders/p4/dw3xhzvn2dx_0k0bdd3nv9_w0000gn/T/ipykernel_93631/2594750248.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   asr_analysis_df = asr_analysis_df.applymap(lambda x: x.lower().translate(str.maketrans('', '', string.punctuation)) if isinstance(x, str) else x)
#                                Original_Transcription  \
# 0   a tornado is a spinning column of very lowpres...
# 1   former us speaker of the house newt gingrich c...
# 2   the island was first inhabited by the taínos a...
# 3   these nerve impulses can be sent so quickly th...
# 4   on september 24 1759 arthur guinness signed a ...
# 5   today timbuktu is an impoverished town althoug...
# 6   with the same time zone as hawaii the islands ...
# 7   hokuriku electric power co reported no effects...
# 8   massa is due to be out for at least the rest o...
# 9   pittman suggested that conditions wouldnt impr...
# 10  followers pursue certain ways of living or pra...
# 11  the protest started around 1100 local time utc...
# 12  the amazon river is the second longest and the...
# 13  virgin have only purchased the good bank of no...
# 14  with this arrangement in place this freedom mi...
# 15  its status declined during the twelfth century...
# 16  the civilisation flourished in the basins of t...
# 17  it was developed by john smith in the 1970s to...
# 18  for some understanding something about how air...
# 19  the original bill was drafted by former mayor ...
# 20  massa is due to be out for at least the rest o...
# 21  there were protests worldwide several criminal...
# 22  despite his comments he said he will be suppor...
# 23  un peacekeepers whom arrived in haiti after th...
# 24  the unmanned lunar orbiter chandrayaan1 ejecte...
# 25  they normally offer higher bandwidth and bette...
# 26  unattended bags are a target for theft and can...
# 27  examples include control planning and scheduli...
# 28  other scientists argue that these plants are v...
# 29  in fact there is not one good thing to learnle...
# 30  permits must be reserved in advance you must h...
# 31  the blade on a modern ice skate has a double e...
# 32  the outerpart we see when we look at the sun i...
# 33  this theory contradicts the claim that the moo...
# 34  another disadvantage of zoom lenses is that th...
# 35  a couple of thousand staff live here in summer...
# 36  unfortunately when you make a dvd its borders ...
# 37  visibility may also be restricted by falling o...
# 38  in essence the renaissance made a significant ...
# 39  historically most farmers were engaged in subs...
# 40  21yearold jesus joined manchester city last ye...
# 41  some people believe that experiencing many art...
# 42  northern rock had required support due to its ...
# 43  in the context of romanticism the geography mo...
# 44  officials for the city of amsterdam and the an...
# 45  we will endeavour to cut carbon dioxide emissi...
# 46  beijing will host the opening and closing cere...
# 47  after the fire the fortress was preserved and ...
# 48  within a few short years following the arrival...
# 49  shortly after the atlanta journalconstitution ...
#
#                                 Whisper_Transcription  \
# 0    a tornado is a spinning column of very low pr...
# 1    former us speaker of the house newt gingrich ...
# 2    the island was first inhabited by the tianos ...
# 3    this nerve empulses can be sent so quickly th...
# 4    on september 24th 1759 arthur guinness signed...
# 5    today timbuktu is an impoverished town althou...
# 6    with the same time zone as hawaii the island ...
# 7    her crookie electric parkour reported no effe...
# 8    masa is due to be out of for at least the res...
# 9    pittman suggested that conditions wouldnt imp...
# 10   followers pursue certain ways of living or pr...
# 11   the protest started around 1100 local time ut...
# 12   the amazon river is the second longest and th...
# 13   version have only purchased the good bank of ...
# 14   with this arrangement in place this freedom m...
# 15   is status declined during the 12th century ma...
# 16   the civilization flourished in the basins of ...
# 17   it was developed by john smith in the 1970s t...
# 18   for some understanding something about how ai...
# 19   the original bill was drafted by former mayor...
# 20   masa is due to be out for at least the rest o...
# 21   there were protests worldwide several crimina...
# 22   despite his comments he said he will be suppo...
# 23   you and peacekeepers who arrived in haiti aft...
# 24   the unmanned lunar orbiter chandrayan 1 injec...
# 25   they normally offer higher bandwidth and bett...
# 26   unattended bags are a target for theft and ca...
# 27   examples include control planning and schedul...
# 28   other scientists argue that these plants are ...
# 29   in fact theres not one good thing to learn le...
# 30   permence must be reserved in advance you must...
# 31   the blade on a modern ice cape has a double e...
# 32   the outer part we see when we look at the sun...
# 33   this theory contradicts the claim that the mo...
# 34   another disadvantage of zoom lenses is that t...
# 35   a couple of thousand staff live here in summe...
# 36   unfortunately when you make a dvd its borders...
# 37   visibility may also be restricted by followin...
# 38   in essence the renaissance made a significant...
# 39   historically most farmers were engaged in sub...
# 40   21yearold jesus joined manchester city last y...
# 41   some people believe that experiencing many ar...
# 42   northern rock had required support due to its...
# 43   in the context of romanticism the geography m...
# 44   officials for the city of amsterdam and the a...
# 45   we will endeavor to cut carbon dioxide emissi...
# 46   beijing will host the opening at closed cerem...
# 47   after the fire the fortress was preserved and...
# 48   within a few short years following the arriva...
# 49   shortly after the atlanta journal constitutio...
#
#                                Wave2Vec_Transcription
# 0   a tornado is a spinning column of very lowpres...
# 1   former ewsh speaker of the house neut gingrich...
# 2   the island was first inhabited by tetianos and...
# 3   these nerve impulses can be sent so quickly th...
# 4   on september twentyfourth seventeen fifty nine...
# 5   today timbactu is an impoverished town althoug...
# 6   with the same time zown as hawai the islands a...
# 7   hokroky electric parko reported no effect from...
# 8   massa is due to be out for at least the rest o...
# 9   pitman suggested that conditions wuldnt improv...
# 10  followers pursue certain ways of living or pra...
# 11  the protest started around eleven the rozero l...
# 12  the amazon river is the secondlongest and the ...
# 13  version have only purchased the good bank of n...
# 14  with this arrangement in place this freedom mi...
# 15  a status declined during the twelfth century m...
# 16  the civilization flourished in the basins of t...
# 17  it was developed by john smith in the nineteen...
# 18  for some understanding something about how air...
# 19  the original bill was drafted by former mayor ...
# 20  massa is due to be out for at least the rest o...
# 21  there were protests worldwide several criminal...
# 22  despite his commets he said he wild be support...
# 23  uvan peacekeepers who arrived in haide after t...
# 24  the unmanned lunar orbiter chandryan wan eject...
# 25  they normally offer higher bandwithan better q...
# 26  unattended bags are a target for theft and can...
# 27  examples include control planning and scheduli...
# 28  other scientists argue that these plants are v...
# 29  in fact there is not one good thing to learn l...
# 30  permits must be reserved in advance you must h...
# 31  the blade on a modern ice cate has a double ed...
# 32  the outer part we see when we look at the sun ...
# 33  this theory contradicts the claim that the moo...
# 34  another disadvantage of zoomlenses is that the...
# 35  a couple of thousand staff live here in summer...
# 36  unfortunately when you make a debd its borders...
# 37  visibility may also be restricted by falling o...
# 38  in essence the renaissance made a significant ...
# 39  historically most pharmers were engaged in sub...
# 40  twentyone yearold jesus joined manchester city...
# 41  some people believe that experiencing many art...
# 42  northern rock had required support due to its ...
# 43  in the context of romanticism the geographymol...
# 44  officials for the city of amsterdam and the an...
# 45  we will endeavor to cut carbon dioxide emissio...
# 46  beijin will host the opening antd closes cerem...
# 47  after the fire the fortress was preserved and ...
# 48  within a few short years following the arrival...
# 49  shortly after the atlanta journal constitution...

# %%
asr_analysis_df['whisper_WER'] = asr_analysis_df.apply(lambda row: wer(row['Original_Transcription'], row['Whisper_Transcription']), axis=1)


mean_wer = asr_analysis_df['whisper_WER'].mean()

print(f"Mean WER: {mean_wer}")
# Out:
# Mean WER: 0.10568459229932642

# %%
asr_analysis_df['wave2vec_WER'] = asr_analysis_df.apply(lambda row: wer(row['Original_Transcription'], row['Wave2Vec_Transcription']), axis=1)


mean_wer = asr_analysis_df['wave2vec_WER'].mean()

print(f"Mean WER: {mean_wer}")
# Out:
# Mean WER: 0.1553863718076332

# %%
# Calculate JW Distance
asr_analysis_df['whisper_JW_Distance'] = asr_analysis_df.apply(lambda row: jarowinkler_similarity(row['Original_Transcription'], row['Whisper_Transcription']), axis=1)

mean_jw = asr_analysis_df['whisper_JW_Distance'].mean()

print(f"Mean Jaro Winkler Distance: {mean_jw}")
# Out:
# Mean Jaro Winkler Distance: 0.8480267675606266

# %%
# Calculate JW Distance
asr_analysis_df['Wave2Vec_JW_Distance'] = asr_analysis_df.apply(lambda row: jarowinkler_similarity(row['Original_Transcription'], row['Wave2Vec_Transcription']), axis=1)

mean_jw = asr_analysis_df['Wave2Vec_JW_Distance'].mean()

print(f"Mean Jaro Winkler Distance: {mean_jw}")
# Out:
# Mean Jaro Winkler Distance: 0.9277293899260606
