# %%
import pandas as pd
from jiwer import wer
import numpy as np
from scipy.spatial.distance import cosine
import gensim
from nltk.tokenize import word_tokenize
import nltk
from gensim.models import KeyedVectors
from huggingface_hub import hf_hub_download

# %%
def clean_translation(text):
    if isinstance(text, str):
        text = text.replace("[{'translation_text': '", "")
        text = text.replace("'}]", "")
        return text
    return text

# Apply the cleaning function

# %%
def get_wer(series1, series2):
    list1 = series1.tolist()
    list2 = series2.tolist()

    wer_scores = [wer(human, machine) for human, machine in zip(list1, list2)]
    return wer_scores

# %%
df = pd.read_csv('translations.csv')
df = df[:50]
df = df['human_translation']

opus = pd.read_csv('translations/opus_translations.csv', header=None)
t5 = pd.read_csv('translations/t5_translations.csv', header=None)

translations = pd.concat([df, opus, t5], axis=1)
header = ['human_translation', 'opus_translation', 't5_translation']
translations.columns = header

translations['opus_translation'] = translations['opus_translation'].apply(clean_translation)
translations['t5_translation'] = translations['t5_translation'].apply(clean_translation)

translations
# Out:
#                                     human_translation  \
# 0   Un tornado es una columna giratoria de aire de...
# 1   El ex Presidente estadounidense de la Cámara, ...
# 2   La isla fue habitada inicialmente vez por los ...
# 3   Estes impulsos nerviosos pueden ser enviados t...
# 4   En el 24 de septiembre de 1759 Arthur Guinness...
# 5   Hoy en día, Tombuctú es una ciudad empobrecida...
# 6   con la misma zona horaria que Hawái, las islas...
# 7   La compañía eléctrica Hokuriku informó que no ...
# 8   Masa debe estar fuera por lo menos el resto de...
# 9   Pittman sugirió que las condiciones no mejorar...
# 10  Los seguidores persiguen ciertas formas de vid...
# 11  La protesta comenzó alrededor de 11-0-0 hora l...
# 12  El río Amazonas es el segundo río más largo y ...
# 13  Virgin sólo ha comprado el ‘buen banco’ de Nor...
# 14  Con este arreglo en su lugar, esta libertad po...
# 15  Su estatus decayó durante el siglo XII, princi...
# 16  La civilización floreció en las cuencas del rí...
# 17  Fue desarrollado por John Smith en la década d...
# 18  Para algunos, entender algo sobre cómo funcion...
# 19  El proyecto de ley original fue redactado por ...
# 20  Masa debe estar fuera por lo menos el resto de...
# 21  Hubo protestas en todo el mundo, varios proces...
# 22  A pesar de sus comentarios, dijo que apoyará a...
# 23  El personal de mantenimiento de la paz del ONU...
# 24  El orbitador lunar no tripulado, Chandrayaan-1...
# 25  Normalmente ofrecen mayor ancho de banda y mej...
# 26  Las bolsas sin asistencia son un objetivo para...
# 27  "Algunos ejemplos incluyen el control, la plan...
# 28  "Otros científicos sostienen que estas plantas...
# 29  "De hecho, no hay nada bueno que aprender. El ...
# 30  Los permisos deben ser reservados con antelaci...
# 31  La cuchilla en un patín de hielo moderno tiene...
# 32  "La parte externa que vemos cuando miramos al ...
# 33  Esta teoría contradice la afirmación de que la...
# 34  "Otra desventaja de las lentes de zoom es que ...
# 35  "Un par de miles de empleados viven aquí en ve...
# 36  "Desafortunadamente, cuando usted hace un DVD,...
# 37  La visibilidad también puede restringirse por ...
# 38  "En esencia, el Renacimiento hizo un cambio si...
# 39  "Históricamente, la mayoría de los agricultore...
# 40  "Jesús, de 21 años, se unió a Manchester City ...
# 41  Algunas personas creen que experimentar muchos...
# 42  Northern Rock había necesitado apoyo debido a ...
# 43  "En el contexto del romanticismo, la geografía...
# 44  Funcionarios de la ciudad de Amsterdam y el Mu...
# 45  Nos esforzaremos por reducir las emisiones de ...
# 46  Beijing será la sede de las ceremonias de aper...
# 47  "Después del incendio, la fortaleza fue preser...
# 48  "Pocos años después de la llegada de los explo...
# 49  "Poco después, el Atlanta Journal Constitution...
#
#                                      opus_translation  \
# 0   Un tornado es una columna giratoria de aire de...
# 1   El ex presidente estadounidense de la casa, Ne...
# 2   La isla fue habitada por primera vez por los T...
# 3   Este nervio se puede enviar tan rápidamente po...
# 4   El 24 de septiembre de 1759 Arthur Guinness fi...
# 5   Hoy en día, Tombuctú es una ciudad empobrecida...
# 6   con la misma zona horaria que Hawái, la isla o...
# 7   Su tortuoso parkour eléctrico informó que no h...
# 8   Masa debe estar fuera por lo menos el resto de...
# 9   Pittman sugirió que las condiciones no mejorar...
# 10  Los seguidores persiguen ciertas formas de vid...
# 11  La protesta comenzó alrededor de 11-0-0 hora l...
# 12  El río Amazonas es el segundo río más largo y ...
# 13  La versión sólo ha comprado el buen banco de N...
# 14  Con este arreglo en su lugar, esta libertad po...
# 15  Su estatus decayó durante el siglo XII, princi...
# 16  La civilización floreció en las cuencas del rí...
# 17  Fue desarrollado por John Smith en la década d...
# 18  Para algunos, entender algo sobre cómo funcion...
# 19  El proyecto de ley original fue redactado por ...
# 20  Masa debe estar fuera por lo menos el resto de...
# 21  Hubo protestas en todo el mundo, varios proces...
# 22  A pesar de sus comentarios, dijo que apoyará a...
# 23  Usted y el personal de mantenimiento de la paz...
# 24  El orbitador lunar no tripulado, Chandrayan 1,...
# 25  Normalmente ofrecen mayor ancho de banda y mej...
# 26  Las bolsas sin asistencia son un objetivo para...
# 27  Algunos ejemplos son el control, la planificac...
# 28  Otros científicos sostienen que estas plantas ...
# 29  De hecho, no hay nada bueno que aprender. El a...
# 30  Permence debe ser reservado por adelantado. Us...
# 31  La hoja en una capa de hielo moderna tiene un ...
# 32  La parte externa que vemos cuando miramos al s...
# 33  Esta teoría contradice la afirmación de que la...
# 34  Otra desventaja de las lentes de zoom es que l...
# 35  Un par de miles de empleados viven aquí en ver...
# 36  Desafortunadamente, cuando usted hace un DVD, ...
# 37  La visibilidad también puede restringirse sigu...
# 38  En esencia, el Renacimiento hizo un cambio sig...
# 39  Históricamente, la mayoría de los agricultores...
# 40  Jesús, de 21 años, se unió a Manchester City e...
# 41  Algunas personas creen que experimentar muchos...
# 42  Northern Rock había necesitado apoyo debido a ...
# 43  En el contexto del romanticismo, la geografía ...
# 44  Funcionarios de la ciudad de Amsterdam y el Mu...
# 45  Nos esforzaremos por reducir las emisiones de ...
# 46  Beijing será el anfitrión de la inauguración e...
# 47  Después del incendio, la fortaleza fue preserv...
# 48  Pocos años después de la llegada de los explor...
# 49  Poco después, el Atlanta Journal Constitution ...
#
#                                        t5_translation
# 0   Un tornado es una columna de aire muy bajo de ...
# 1   El antiguo orador estadounidense de la casa, N...
# 2   La isla fue habitada por los trópicos y los Ca...
# 3   Este músculo se puede enviar tan rápidamente a...
# 4   El 24 de septiembre de 1759, Arthur Guinness f...
# 5   Hoy en día, Timbuktu es una ciudad desfavoreci...
# 6   con la misma zona horaria que Hawaii, la isla ...
# 7   Su parkour eléctrico crookie no informó de que...
# 8   Masa se espera que se mantenga al menos por el...
# 9   Pittman sugirió que las condiciones no mejorar...
# 10  Los seguidores buscan ciertas formas de vida o...
# 11  La protesta comenzó alrededor de 11-0-0 en la ...
# 12  El Amazonas es el segundo río más largo y más ...
# 13  La versión sólo ha comprado el buen banco de N...
# 14  Con este arreglo en marcha, esta libertad pued...
# 15  Su situación se deterioró durante el siglo XII...
# 16  La civilización floreció en las cuencas del rí...
# 17  Fue desarrollado por John Smith en los años 70...
# 18  Para algunos, entender algo acerca de cómo fun...
# 19  El proyecto de ley original fue elaborado por ...
# 20  Masa se espera que finalice al menos el resto ...
# 21  Se realizaron protestas en todo el mundo, vari...
# 22  A pesar de sus comentarios, ha declarado que a...
# 23  Tus amigos y compañeros de paz que llegaron a ...
# 24  El orbiter lunar, Chandrayan 1, inyecta su pro...
# 25  Normalmente ofrecen un mayor ancho de banda y ...
# 26  Las bolsas no autorizadas son objetivo de robo...
# 27  Algunos ejemplos incluyen control, planificaci...
# 28  Otros científicos sostienen que estas plantas ...
# 29  De hecho, no hay nada bueno para aprender, la ...
# 30             El hotel no dispone de parking propio.
# 31  La hoja de un moderno cubo de hielo tiene un d...
# 32  La parte exterior que vemos cuando miramos al ...
# 33  Esta teoría contrasta con la afirmación de que...
# 34  Otra desventaja de los objetivos zoom es que l...
# 35  En verano, la mayoría de las zonas de la ciuda...
# 36  Desafortunadamente, cuando haces un DVD, sus b...
# 37  La visibilidad puede ser restringida por la pr...
# 38  En esencia, el Renacimiento hizo un cambio sig...
# 39  Históricamente, la mayoría de los campesinos s...
# 40  El año pasado, Jesús se unió a la ciudad de Ma...
# 41  Algunas personas creen que experimentar muchos...
# 42  El Norte de Rock había requerido apoyo debido ...
# 43  En el contexto del romanticismo, la geografía ...
# 44  Los funcionarios de la ciudad de Ámsterdam y d...
# 45  En el año 2005 se espera que la reducción de e...
# 46  Beijing acogerá la apertura de ceremonias cerr...
# 47  Tras el fuego, la fortaleza fue preservada y p...
# 48  En pocos años después de la llegada de los exp...
# 49  Poco después, la Constitución del New York Tim...

# %%
#opus wer
human_translation = translations['human_translation']
opus_translation = translations['opus_translation']
wer_scores = get_wer(human_translation, opus_translation)
mean_wer = sum(wer_scores)/len(wer_scores)
mean_wer
# Out:
# 0.15333000759579127

# %%
#t5 wer
human_translation = translations['human_translation']
t5_translation = translations['t5_translation']
wer_scores = get_wer(human_translation, t5_translation)
mean_wer = sum(wer_scores)/len(wer_scores)
mean_wer
# Out:
# 0.4547647596981374

# %%
spanish_model = KeyedVectors.load_word2vec_format(hf_hub_download(repo_id="Word2vec/wikipedia2vec_eswiki_20180420_300d", filename="eswiki_20180420_300d.txt"))

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/averyfield/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
human_text = translations['human_translation'].dropna().tolist()
opus_text = translations['opus_translation'].dropna().tolist()

# Tokenize and preprocess
def preprocess_text(text):
    # Tokenize and lowercase
    return word_tokenize(text.lower())

human_tokenized = [preprocess_text(sentence) for sentence in human_text]
opus_tokenized = [preprocess_text(sentence) for sentence in opus_text]

# Function to get embeddings for a sentence by averaging word embeddings
def get_sentence_embedding(sentence, model):
    embeddings = [model[word] for word in sentence if word in model]
    if embeddings:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(model.vector_size)

# Get sentence embeddings for human and opus translated text
human_embeddings = [get_sentence_embedding(sentence, spanish_model) for sentence in human_tokenized]
opus_embeddings = [get_sentence_embedding(sentence, spanish_model) for sentence in opus_tokenized]

opus_cosine_distances = []

# Calculate cosine distance between corresponding human and opus translation embeddings
for human_emb, opus_emb in zip(human_embeddings, opus_embeddings):
    if human_emb is not None and opus_emb is not None:
        dist = cosine(human_emb, opus_emb)  # Cosine distance
    else:
        dist = None  # Handle cases where embeddings couldn't be calculated
    opus_cosine_distances.append(dist)

mean_cd = sum(opus_cosine_distances)/len(opus_cosine_distances)
print(f"Mean Cosine Distance: {mean_cd}")
# Out:
# Mean Cosine Distance: 0.010252138527626903

# %%
human_text = translations['human_translation'].dropna().tolist()
t5_text = translations['t5_translation'].dropna().tolist()

# Tokenize and preprocess
def preprocess_text(text):
    # Tokenize and lowercase
    return word_tokenize(text.lower())

human_tokenized = [preprocess_text(sentence) for sentence in human_text]
t5_tokenized = [preprocess_text(sentence) for sentence in t5_text]

# Function to get embeddings for a sentence by averaging word embeddings
def get_sentence_embedding(sentence, model):
    embeddings = [model[word] for word in sentence if word in model]
    if embeddings:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(model.vector_size)

# Get sentence embeddings for human and t5 translated text
human_embeddings = [get_sentence_embedding(sentence, spanish_model) for sentence in human_tokenized]
t5_embeddings = [get_sentence_embedding(sentence, spanish_model) for sentence in t5_tokenized]

t5_cosine_distances = []

# Calculate cosine distance between corresponding human and t5 translation embeddings
for human_emb, t5_emb in zip(human_embeddings, t5_embeddings):
    if human_emb is not None and t5_emb is not None:
        dist = cosine(human_emb, t5_emb)  # Cosine distance
    else:
        dist = None  # Handle cases where embeddings couldn't be calculated
    t5_cosine_distances.append(dist)

mean_cd = sum(t5_cosine_distances)/len(t5_cosine_distances)
print(f"Mean Cosine Distance: {mean_cd}")
# Out:
# Mean Cosine Distance: 0.0363625209250241
